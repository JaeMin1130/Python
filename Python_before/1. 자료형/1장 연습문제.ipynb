# %%
#문자열 Q1
pin='881120-1068234'        #문자열이어야 한다
yyyymmdd=pin[:6]
num=pin[7:]
print(yyyymmdd)
print(num)

#Q2
print(pin[7])

#리스트 Q1
a=[1,3,5,4,2]
a.sort()
a.reverse()
print(a)

#Q2
a=['Life','is','too','short']
print(' '.join(a))

#튜플 Q1
a=(1,2,3)
a=a+(4,)
print(a)

#딕셔너리 Q1
a={'A':90,'B':80,'C':70}
result=a.pop('B')
print(a)
print(result)

#집합 Q1
a=[1,1,1,2,2,3,3,3,4,4,5]
aSet=set(a)
b=list(aSet)
print(b)

#변수 Q1
a=b=[1,2,3]
a[1]=4
print(b)
b=a[:]
from copy import copy  #a,b가 다른 리스트로 인식되게 하기
b=copy(a)
# Out:
# 881120
# 1068234
# 1
# [5, 4, 3, 2, 1]
# Life is too short
# (1, 2, 3, 4)
# {'A': 90, 'C': 70}
# 80
# [1, 2, 3, 4, 5]
# [1, 4, 3]
