# %%
# input
while a!='puddle':
  a=input('Which kind of dog is it?: ')

while c != 2:
  c=int(input('1+1= '))

# %%
# print 
#따옴표로 둘러싸인 문자열은 + 연산과 동일하다.
print('A dog' ' is' ' cute')
print('A dog'+' is'+' cute')

#문자열 띄어쓰기는 콤마로 한다.
print('A dog','is','cute')

#한 줄에 출력하기
print([a*b for a in [1,2,3] for b in (2,3,4)], end='')
